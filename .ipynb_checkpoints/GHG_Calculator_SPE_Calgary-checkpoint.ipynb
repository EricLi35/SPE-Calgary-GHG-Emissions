# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
years = list(range(2020, 2003, -1))
data_list = []

for year in years:
    file_path = f"./data/Greenhouse Gas Emissions_{year}.csv"
    data = pd.read_csv(file_path)
    if 'HFCs' in data.columns:
        data.rename(columns={'HFCs': 'HFC', 'PFCs': 'PFC'}, inplace=True)
    data_list.append(data)

finaldata = pd.concat(data_list)


all_years = data_list[::-1]  

# len(all_years)

# %% [markdown]
# Convert CH4, SF6, HFC, PFC, and N2O to CO2 equivalent emissions:

# %%
list(finaldata)
# Out:
# ['Year',
#  'GHGRP ID',
#  'National Pollutant Release Inventory (NPRI) identifier',
#  'Company & facility name',
#  'NAICS',
#  'City',
#  'Province / territory',
#  'CO2',
#  'CH4',
#  'N20',
#  'HFC',
#  'PFC',
#  'SF6',
#  'Total',
#  'PDGES ID',
#  'NPRI',
#  'Company name and facility',
#  'Town',
#  'Province']

# %%
finaldata
# Out:
#     Year GHGRP ID  National Pollutant Release Inventory (NPRI) identifier  \
# 0   2020   G10327                                            19289.0
# 1   2020   G10152                                             6556.0
# 2   2020   G10097                                              126.0
# 3   2020   G11056                                             2630.0
# 4   2020   G11174                                             4468.0
# ..   ...      ...                                                ...
# 93  2004   G10314                                             4138.0
# 94  2004   G10316                                              280.0
# 95  2004   G10321                                             3751.0
# 96  2004   G10324                                             4136.0
# 97  2004   G10326                                             5285.0
#
#                               Company & facility name   NAICS  \
# 0              Rio Tinto Alcan Inc - Strathcona Works  324190
# ...

# %%
all_years_gases = []

for i in range(len(all_years)):
    all_years_gases.append(all_years[i][["CH4","N20","HFC","PFC","SF6"]])

# finaldata = finaldata[["CH4","N20","HFC","PFC","SF6"]]
# finaldata

all_years_gases[9]
# Out:
#               CH4           N20  HFC  PFC     SF6
# 0     12804.42788   3323.892000  0.0  0.0  0.0000
# 1     62566.39945  13010.680300  0.0  0.0  0.0000
# 2       489.34750    433.202600  0.0  0.0  0.0000
# 3     26224.41520   3834.783200  0.0  0.0  0.0000
# 4      2042.01245  17245.260300  0.0  0.0  0.0000
# ..            ...           ...  ...  ...     ...
# 166   10838.40275   1180.735600  0.0  0.0  0.0000
# 167   14669.17450    477.694000  0.0  0.0  0.0000
# 168  184931.14630   7728.928298  0.0  0.0  0.0000
# 169     349.22000    349.285800  0.0  0.0  3.4656
# 170      28.54000    321.810200  0.0  0.0  0.0000
#
# [171 rows x 5 columns]

# %%
finaldata
# Out:
#     Year GHGRP ID  National Pollutant Release Inventory (NPRI) identifier  \
# 0   2020   G10327                                            19289.0
# 1   2020   G10152                                             6556.0
# 2   2020   G10097                                              126.0
# 3   2020   G11056                                             2630.0
# 4   2020   G11174                                             4468.0
# ..   ...      ...                                                ...
# 93  2004   G10314                                             4138.0
# 94  2004   G10316                                              280.0
# 95  2004   G10321                                             3751.0
# 96  2004   G10324                                             4136.0
# 97  2004   G10326                                             5285.0
#
#                               Company & facility name   NAICS  \
# 0              Rio Tinto Alcan Inc - Strathcona Works  324190
# ...

# %%
def Convert_CO2(data,GWP):
  result = np.zeros(np.shape(data))
  for i in range(5):
    result[:,i] = data.iloc[:,i]*GWP[i]*0.001
    data.iloc[:,i] = result[:,i]
  return data

# %% [markdown]
# GWP (global warming potential) is a property applied to greenhouse gases, which indicates the amount of warming a gas causes over a certain period of time (typically 100 years). All GWP values of other GHGs are a multiplier of CO2's GWP value, which is 1. Methane (CH4) has a GWP value of 25, meaning 1kg of CH4 causes 25 times more warming over 100 year span compared to 1kg of CO2.
#
# https://ecometrica.com/assets/GHGs-CO2-CO2e-and-Carbon-What-Do-These-Mean-v2.1.pdf

# %% [markdown]
# Carbon dioxide equivalent (CO2e) is a term that essentially converts different GHG into some measurement comparable to CO2 emissions. This allows the use of a common unit, leading to more comparisions and anaylsis being performed. CO2e signifies the equivalent amount of CO2 in terms of impact on global warming.
#
# CO2e can be calculated by multiplying a GHG amount by its corresponding GWP. For example if CH4 has a GWP of 25, then 1kg of CH4 emissions = 25kg CO2e

# %% [markdown]
# Global warming potentials for CH4, N2O, SF6, PFC, and HFC

# %%
GWP_CH4 = 25
GWP_N2O = 298
GWP_SF6 = 23900
GWP_PFC = 7390
GWP_HFC = 3500
GWP = [GWP_CH4,GWP_N2O,GWP_HFC,GWP_PFC,GWP_SF6]

# %%
finaldata
# Out:
#     Year GHGRP ID  National Pollutant Release Inventory (NPRI) identifier  \
# 0   2020   G10327                                            19289.0
# 1   2020   G10152                                             6556.0
# 2   2020   G10097                                              126.0
# 3   2020   G11056                                             2630.0
# 4   2020   G11174                                             4468.0
# ..   ...      ...                                                ...
# 93  2004   G10314                                             4138.0
# 94  2004   G10316                                              280.0
# 95  2004   G10321                                             3751.0
# 96  2004   G10324                                             4136.0
# 97  2004   G10326                                             5285.0
#
#                               Company & facility name   NAICS  \
# 0              Rio Tinto Alcan Inc - Strathcona Works  324190
# ...

# %%
CO2e = []
for i in range(len(all_years_gases)):
    CO2e.append(Convert_CO2(all_years_gases[i], GWP)) 


finaldata_CO2 = Convert_CO2(finaldata.iloc[:,8:13], GWP)
finaldata_CO2.head(6)
# Out:
#         CH4         N20     HFC  PFC  SF6
# 0  0.060054    2.144173     0.0  0.0  0.0
# 1  2.476355  190.493194     0.0  0.0  0.0
# 2  3.868750   55.591304  2674.7  0.0  0.0
# 3  0.306186   31.222066     0.0  0.0  0.0
# 4  0.183063   23.068615     0.0  0.0  0.0
# 5  0.088263   11.205289     0.0  0.0  0.0

# %%
CO2e[2]
# Out:
#              CH4          N20  HFC  PFC  SF6
# 0     202.411257  1046.999160  0.0  0.0  0.0
# 1     256.862505  3819.460040  0.0  0.0  0.0
# 2      35.000000   612.747600  0.0  0.0  0.0
# 3    1663.937492  1107.474684  0.0  0.0  0.0
# 4      56.879373  5559.823160  0.0  0.0  0.0
# ..           ...          ...  ...  ...  ...
# 98      2.387500   240.658840  0.0  0.0  0.0
# 99      0.000000   414.776843  0.0  0.0  0.0
# 100   671.577378  1928.618631  0.0  0.0  0.0
# 101    81.110626   586.994440  0.0  0.0  0.0
# 102    29.600001     4.173788  0.0  0.0  0.0
#
# [103 rows x 5 columns]

# %%
def totalCO2(data1,data2):
    data1 = pd.concat([data1, pd.DataFrame(columns = ['Total', 'CO2'])], sort = True)
    data1['CO2'] = data2['CO2']
    data1['Total'] = data1.iloc[:, :5].sum(axis=1)
    return data1

# %% [markdown]
# After converting all GHGs data to CO2, calculate the total CO2

# %%
CO2_total = []

for i in range(len(CO2e)):
    CO2_total.append(totalCO2(CO2e[i], all_years[i]))

# %%
Final_data = totalCO2(finaldata_CO2, finaldata)
Final_data
# Out:
#             CH4           CO2      HFC          N20  PFC  SF6         Total
# 0      0.060054  9.026367e+04      0.0     2.144173  0.0  0.0  9.026588e+04
# 1      2.476355  1.420877e+05      0.0   190.493194  0.0  0.0  1.422806e+05
# 2      3.868750  2.459208e+04   2674.7    55.591304  0.0  0.0  2.732624e+04
# 3      0.306186  2.216255e+04      0.0    31.222066  0.0  0.0  2.219408e+04
# 4      0.183063  1.556311e+04      0.0    23.068615  0.0  0.0  1.558636e+04
# ..          ...           ...      ...          ...  ...  ...           ...
# 93   326.093750  1.283855e+05      0.0   875.607440  0.0  0.0  1.295872e+05
# 94    41.036876  1.426222e+06  16016.0   649.334848  0.0  0.0  1.442928e+06
# 95   116.501875  1.534819e+05      0.0   938.995735  0.0  0.0  1.545374e+05
# 96  1096.624971  1.401719e+06      0.0  3086.294394  0.0  0.0  1.405902e+06
# 97   870.347519  1.019425e+05      0.0   427.289326  0.0  0.0  1.032401e+05
#
# [4662 rows x 7 columns]

# %%
CO2_total[1]
# Out:
#             CH4           CO2  HFC          N20  PFC  SF6         Total
# 0    328.549992  3.250187e+05  0.0  1285.881920  0.0  0.0  3.266331e+05
# 1    237.493741  1.054456e+06  0.0  5012.097760  0.0  0.0  1.059705e+06
# 2     31.875000  3.187210e+05  0.0   568.345600  0.0  0.0  3.193212e+05
# 3   1079.687481  5.332178e+05  0.0  1111.914884  0.0  0.0  5.354094e+05
# 4     55.199938  7.878815e+04  0.0  5369.613784  0.0  0.0  8.421296e+04
# ..          ...           ...  ...          ...  ...  ...           ...
# 94     0.014375  1.012180e+05  0.0     1.420864  0.0  0.0  1.012194e+05
# 95     0.625000  1.767600e+04  0.0     0.000000  0.0  0.0  1.767662e+04
# 96     0.000000  1.222000e+03  0.0     0.000000  0.0  0.0  1.222000e+03
# 97     0.000000  4.574000e+03  0.0     0.000000  0.0  0.0  4.574000e+03
# 98  8286.250000  0.000000e+00  0.0     0.000000  0.0  0.0  8.286250e+03
#
# [99 rows x 7 columns]

# %% [markdown]
# GHGs emissions from 2004-2020

# %%
# Years = list(range(2004, 2021))

# CO2_em = pd.DataFrame(columns=Years)
# CH4_em = pd.DataFrame(columns=Years)
# N2O_em = pd.DataFrame(columns=Years)
# HFC_em = pd.DataFrame(columns=Years)
# PFC_em = pd.DataFrame(columns=Years)
# SF6_em = pd.DataFrame(columns=Years)


# for i, year in enumerate(range(2004, 2021)):
#     CO2_em[str(year)] = CO2_total[i]['CO2']
#     CH4_em[str(year)] = CO2_total[i]['CH4']
#     N2O_em[str(year)] = CO2_total[i]['N20']
#     HFC_em[str(year)] = CO2_total[i]['HFC']
#     PFC_em[str(year)] = CO2_total[i]['PFC']
#     SF6_em[str(year)] = CO2_total[i]['SF6']
    

# Years_CO2 = CO2_em.sum()[17:].to_list()
# Years_CH4 = CH4_em.sum()[17:].to_list()
# Years_N2O = N2O_em.sum()[17:].to_list()
# Years_HFC = HFC_em.sum()[17:].to_list()
# Years_PFC = PFC_em.sum()[17:].to_list()
# Years_SF6 = SF6_em.sum()[17:].to_list()


# Years_SF6

# %%
Years = list(range(2004, 2021))

emission_data = {}

for emission in ['CO2', 'CH4', 'N20', 'HFC', 'PFC', 'SF6']:
    emission_data[emission + '_em'] = pd.DataFrame(columns=Years)

for i, year in enumerate(range(2004, 2021)):
    for emission in ['CO2', 'CH4', 'N20', 'HFC', 'PFC', 'SF6']:
        emission_data[emission + '_em'][str(year)] = CO2_total[i][emission]

Years_CO2 = emission_data['CO2_em'].sum()[17:].to_list()
Years_CH4 = emission_data['CH4_em'].sum()[17:].to_list()
Years_N2O = emission_data['N20_em'].sum()[17:].to_list()
Years_HFC = emission_data['HFC_em'].sum()[17:].to_list()
Years_PFC = emission_data['PFC_em'].sum()[17:].to_list()
Years_SF6 = emission_data['SF6_em'].sum()[17:].to_list()

# %%
Years_CO2
# Out:
# [102757222.697175,
#  101704740.487304,
#  108213419.30991401,
#  107172251.080128,
#  96495110.50954,
#  93441743.258829,
#  96695682.189923,
#  97608543.17555101,
#  96222339.067363,
#  98313155.75493,
#  103287287.72958802,
#  105486023.718587,
#  93434105.46121201,
#  42161902.78927901,
#  57130469.537750006,
#  17135730.367318,
#  12179515.583351001]

# %% [markdown]
# red dashes, blue line, green stars, black dots, yellow triangles,

# %%
plt.subplot(6,2,1)
plt.plot(Years, Years_CO2, 'r--')
plt.xlabel("CO2 Emissions in Alberta")
plt.ylabel("Metric Tons")
plt.subplot(6,2,2)
plt.plot(Years, Years_CH4, 'b-.')
plt.xlabel("CH4 Emissions in Alberta")
plt.ylabel("Metric Tons")
plt.subplot(6,2,3)
plt.plot(Years, Years_N2O, 'g--')
plt.xlabel("N2O Emissions in Alberta")
plt.ylabel("Metric Tons")
plt.subplot(6,2,4)
plt.plot(Years, Years_HFC, 'k--')
plt.xlabel("HFC Emissions in Alberta")
plt.ylabel("Metric Tons")
plt.subplot(6,2,5)
plt.plot(Years, Years_PFC, 'y-.')
plt.xlabel("PFC Emissions in Alberta")
plt.ylabel("Metric Tons")
plt.subplot(6,2,6)
plt.plot(Years, Years_SF6, 'm--')
plt.xlabel("SF6 Emissions in Alberta")
plt.ylabel("Metric Tons")
plt.subplots_adjust(top=6, bottom=0, left=0, right=3, hspace=0.25,
                    wspace=0.25)
plt.show()

# %%
plt.plot(Years, np.array(Years_CO2) + np.array(Years_CH4) + np.array(Years_HFC) + np.array(Years_N2O) +np.array(Years_PFC) + np.array(Years_SF6), 'r--')
plt.xlabel("CO2 Emissions in Alberta")
plt.ylabel("Metric Tons")
plt.xticks(rotation=45)
plt.show()

# %%
finaldata
# Out:
#     Year GHGRP ID  National Pollutant Release Inventory (NPRI) identifier  \
# 0   2020   G10327                                            19289.0
# 1   2020   G10152                                             6556.0
# 2   2020   G10097                                              126.0
# 3   2020   G11056                                             2630.0
# 4   2020   G11174                                             4468.0
# ..   ...      ...                                                ...
# 93  2004   G10314                                             4138.0
# 94  2004   G10316                                              280.0
# 95  2004   G10321                                             3751.0
# 96  2004   G10324                                             4136.0
# 97  2004   G10326                                             5285.0
#
#                               Company & facility name   NAICS  \
# 0              Rio Tinto Alcan Inc - Strathcona Works  324190
# ...

# %%
Final_data
# Out:
#             CH4           CO2      HFC          N20  PFC  SF6         Total
# 0      0.060054  9.026367e+04      0.0     2.144173  0.0  0.0  9.026588e+04
# 1      2.476355  1.420877e+05      0.0   190.493194  0.0  0.0  1.422806e+05
# 2      3.868750  2.459208e+04   2674.7    55.591304  0.0  0.0  2.732624e+04
# 3      0.306186  2.216255e+04      0.0    31.222066  0.0  0.0  2.219408e+04
# 4      0.183063  1.556311e+04      0.0    23.068615  0.0  0.0  1.558636e+04
# ..          ...           ...      ...          ...  ...  ...           ...
# 93   326.093750  1.283855e+05      0.0   875.607440  0.0  0.0  1.295872e+05
# 94    41.036876  1.426222e+06  16016.0   649.334848  0.0  0.0  1.442928e+06
# 95   116.501875  1.534819e+05      0.0   938.995735  0.0  0.0  1.545374e+05
# 96  1096.624971  1.401719e+06      0.0  3086.294394  0.0  0.0  1.405902e+06
# 97   870.347519  1.019425e+05      0.0   427.289326  0.0  0.0  1.032401e+05
#
# [4662 rows x 7 columns]

# %%
finaldata
# Out:
#     Year GHGRP ID  National Pollutant Release Inventory (NPRI) identifier  \
# 0   2020   G10327                                            19289.0
# 1   2020   G10152                                             6556.0
# 2   2020   G10097                                              126.0
# 3   2020   G11056                                             2630.0
# 4   2020   G11174                                             4468.0
# ..   ...      ...                                                ...
# 93  2004   G10314                                             4138.0
# 94  2004   G10316                                              280.0
# 95  2004   G10321                                             3751.0
# 96  2004   G10324                                             4136.0
# 97  2004   G10326                                             5285.0
#
#                               Company & facility name   NAICS  \
# 0              Rio Tinto Alcan Inc - Strathcona Works  324190
# ...

# %%
for i in range(len(all_years_gases)):
    all_years_gases[i].loc[:,["CO2","CH4","N20","HFC","PFC","SF6","Total"]] = CO2_total[i][["CO2","CH4","N20","HFC","PFC","SF6","Total"]]
finaldata[["CO2","CH4","N20","HFC","PFC","SF6","Total"]] = Final_data[["CO2","CH4","N20","HFC","PFC","SF6","Total"]]

# %%
print(finaldata.shape)
print(Final_data.shape)
print(list(finaldata))
print(list(Final_data))
# Out:
# (4662, 19)
# (4662, 7)
# ['Year', 'GHGRP ID', 'National Pollutant Release Inventory (NPRI) identifier', 'Company & facility name', 'NAICS', 'City', 'Province / territory', 'CO2', 'CH4', 'N20', 'HFC', 'PFC', 'SF6', 'Total', 'PDGES ID', 'NPRI', 'Company name and facility', 'Town', 'Province']
# ['CH4', 'CO2', 'HFC', 'N20', 'PFC', 'SF6', 'Total']

# %%
Final_data.describe()
# Out:
#                 CH4           CO2           HFC            N20          PFC  \
# count   4662.000000  4.662000e+03   4662.000000    4662.000000  4662.000000
# mean     396.593697  4.539065e+05    147.904690    1484.074496     2.454954
# std     1654.425774  1.484349e+06   1896.932674    8403.860199    60.858938
# min        0.000000  0.000000e+00      0.000000       0.000000     0.000000
# 25%       21.471093  1.218119e+04      0.000000      31.691927     0.000000
# 50%       77.816656  4.470564e+04      0.000000     164.831324     0.000000
# 75%      217.619953  2.087118e+05      0.000000     673.326359     0.000000
# max    34885.326975  1.627313e+07  66011.634500  231963.329928  2767.850600
#
#                 SF6         Total
# count   4662.000000  4.662000e+03
# mean     110.204635  4.559376e+05
# std     1455.272659  1.488312e+06
# min        0.000000  1.244640e+00
# 25%        0.000000  1.279499e+04
# 50%        0.000000  4.546647e+04
# 75%        0.000000  2.107875e+05
# ...

# %%
finaldata[["PDGES ID","NPRI","NAICS","Province"]]
# Out:
#    PDGES ID  NPRI   NAICS Province
# 0       NaN   NaN  324190      NaN
# 1       NaN   NaN  325110      NaN
# 2       NaN   NaN  325210      NaN
# 3       NaN   NaN  327214      NaN
# 4       NaN   NaN  311224      NaN
# ..      ...   ...     ...      ...
# 93      NaN   NaN  211113      NaN
# 94      NaN   NaN  325190      NaN
# 95      NaN   NaN  211113      NaN
# 96      NaN   NaN  211114      NaN
# 97      NaN   NaN  211113      NaN
#
# [4662 rows x 4 columns]

# %% [markdown]
# Drop the 'PDGES ID','NPRI','NAICS','Province'data

# %%
finaldata = finaldata.drop(['PDGES ID','NPRI','NAICS','Province','National Pollutant Release Inventory (NPRI) identifier'], axis = 1)

# %%
finaldata.head()
# Out:
#    Year GHGRP ID                            Company & facility name  \
# 0  2020   G10327             Rio Tinto Alcan Inc - Strathcona Works
# 1  2020   G10152        INEOS Canada Partnership - Joffre LAO Plant
# 2  2020   G10097               Celanese Canada ULC. - Edmonton Site
# 3  2020   G11056       Johns Manville Canada Inc. - Innisfail Plant
# 4  2020   G11174  Bunge Canada  - BUNGE CANADA - FORT SASKATCHEW...
#
#               City Province / territory            CO2       CH4         N20  \
# 0    Sherwood Park              Alberta   90263.674514  0.060054    2.144173
# 1           Joffre              Alberta  142087.672587  2.476355  190.493194
# 2         Edmonton              Alberta   24592.080000  3.868750   55.591304
# 3        Innisfail              Alberta   22162.550770  0.306186   31.222066
# 4  Sturgeon County              Alberta   15563.110000  0.183063   23.068615
#
#       HFC  PFC  SF6          Total Company name and facility Town
# ...

# %% [markdown]
# # create train group and test group from final data

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(finaldata, test_size=0.2, random_state=42)

# %%
train_set
# Out:
#      Year GHGRP ID                            Company & facility name  \
# 32   2006   G10108  Duke Energy Empress LP - Empress straddle plan...
# 332  2020   G10371          NAL Resources Management - Olds Gas Plant
# 411  2019      NaN                                                NaN
# 49   2019      NaN                                                NaN
# 18   2019      NaN                                                NaN
# ..    ...      ...                                                ...
# 64   2006   G10211  NOVA Chemicals Corporation - NOVA Chemicals Co...
# 466  2020   G11463       Tourmaline Oil Corp - Harley 08-10-057-27-W5
# 131  2015      NaN                                                NaN
# 110  2011      NaN                                                NaN
# 158  2019      NaN                                                NaN
#
#             City Province / territory           CO2         CH4          N20  \
# ...

# %%
test_set
# Out:
#      Year GHGRP ID                            Company & facility name  \
# 566  2019      NaN                                                NaN
# 95   2009   G10361  Air Products Canada Ltd. - Edmonton Hydrogen F...
# 373  2018      NaN                                                NaN
# 23   2020   G10870        Ovintiv Canada ULC - Kaybob Gas Plant 15-31
# 472  2019      NaN                                                NaN
# ..    ...      ...                                                ...
# 428  2017      NaN                                                NaN
# 191  2016      NaN                                                NaN
# 95   2007   G10356                  Nexen Inc. - Balzac Power Station
# 28   2010      NaN                                                NaN
# 36   2004   G10112           Lafarge Canada Inc - Exshaw Cement Plant
#
#                City Province / territory           CO2         CH4  \
# ...

# %%
GHGs = train_set.drop("Total", axis=1) # drop labels for training set
GHGs_labels = train_set["Total"].copy()

# %%
GHGs_labels.head()
# Out:
# 32     367999.054998
# 332     91384.683846
# 411     13171.197207
# 49     528746.302581
# 18       6086.632913
# Name: Total, dtype: float64

# %% [markdown]
# but need to take out the string keys does not work

# %%
GHGs_prepared = GHGs.drop(["Company name and facility","Town", "Year","GHGRP ID", "Company & facility name", "Province / territory", "City"], axis=1)
GHGs_prepared.head()
# Out:
#              CO2         CH4          N20  HFC  PFC  SF6
# 32   367230.4000  102.624998   666.030000  0.0  0.0  0.0
# 332   90988.9720   20.603750   375.108096  0.0  0.0  0.0
# 411   12989.4640  161.041875    20.691332  0.0  0.0  0.0
# 49   526826.7473  494.837188  1424.718094  0.0  0.0  0.0
# 18     5884.1515  140.647188    61.834225  0.0  0.0  0.0

# %%
GHGs.head()
# Out:
#      Year GHGRP ID                            Company & facility name  \
# 32   2006   G10108  Duke Energy Empress LP - Empress straddle plan...
# 332  2020   G10371          NAL Resources Management - Olds Gas Plant
# 411  2019      NaN                                                NaN
# 49   2019      NaN                                                NaN
# 18   2019      NaN                                                NaN
#
#         City Province / territory          CO2         CH4          N20  HFC  \
# 32   EMPRESS              Alberta  367230.4000  102.624998   666.030000  0.0
# 332      NaN              Alberta   90988.9720   20.603750   375.108096  0.0
# 411      NaN                  NaN   12989.4640  161.041875    20.691332  0.0
# 49       NaN                  NaN  526826.7473  494.837188  1424.718094  0.0
# 18       NaN                  NaN    5884.1515  140.647188    61.834225  0.0
#
#      PFC  SF6                          Company name and facility     Town
# ...

# %%
GHGs_prepared.shape
# Out:
# (3729, 6)

# %% [markdown]
# # Build a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()
tree_reg.fit(GHGs_prepared, GHGs_labels)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import mean_squared_error
GHGs_predict = tree_reg.predict(GHGs_prepared)
tree_mse = mean_squared_error(GHGs_labels, GHGs_predict)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 0.0

# %% [markdown]
# Cross Validation our tree decision results.

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(tree_reg, GHGs_prepared, GHGs_labels, scoring = "neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
  print("Scores:", scores)
  print("Mean:", scores.mean())
  print("Standard deviation:", scores.std())

# %%
display_scores(tree_rmse_scores)
# Out:
# Scores: [75784.0893938  24304.32667523 52686.08672261 40529.84113332
#  18723.65617905 44440.82637164 23580.03385639 16105.59634397
#  11120.49488324 24401.83726872]
# Mean: 33167.67888279818
# Standard deviation: 19004.096085321453

# %%
df = train_set["Year"]
GHGs_predict = pd.DataFrame(GHGs_predict)
GHGs_predict=GHGs_predict.to_numpy()
df=df.to_numpy()
GHGs_predict = GHGs_predict.reshape((np.size(GHGs_predict)),1)
df = df.reshape((np.size(df),1))
GHGs_predict=np.concatenate((GHGs_predict,df), axis = 1)

# %%
GHGs_predict = pd.DataFrame(GHGs_predict)

# %%
predict_DT_Result = np.zeros(np.size(Years))
predict_DT_Result[0]
for i in range(2004,2021):
  a = i-2004
  predict_DT_Result[a]=np.sum(GHGs_predict.loc[GHGs_predict[1]==i].to_numpy())

# %% [markdown]
# # Plot: Prediction of Total emissions for each year

# %%
plt.plot(Years, predict_DT_Result, 'k--', label='Predicted Emissions (Decision Trees)')
plt.plot(Years, np.array(Years_CO2) + np.array(Years_CH4) + np.array(Years_HFC) + np.array(Years_N2O) +np.array(Years_PFC) + np.array(Years_SF6), 'r--', label='Actual Emissions')
plt.legend(loc="lower left")
plt.xlabel("Years")
plt.ylabel("Metric Tons eCO2")
# Out:
# Text(0, 0.5, 'Metric Tons eCO2')

# %%
from sklearn.linear_model import LinearRegression
print("GHGs",GHGs.shape,type(GHGs))
print("GHGs_prepared",GHGs_prepared.shape)
print("GHGs_labels",GHGs_labels.shape)
lin_reg = LinearRegression()
lin_reg.fit(GHGs_prepared, GHGs_labels)
GHGs_linPredict = lin_reg.predict(GHGs_prepared)
lin_mse = mean_squared_error(GHGs_labels, GHGs_linPredict)
lin_rmse = np.sqrt(lin_mse)
# Out:
# GHGs (3729, 13) <class 'pandas.core.frame.DataFrame'>
# GHGs_prepared (3729, 6)
# GHGs_labels (3729,)

# %%
scores_lin = cross_val_score(lin_reg, GHGs_prepared, GHGs_labels, scoring = "neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-scores_lin)
display_scores(lin_rmse_scores)
# Out:
# Scores: [8.23549325e-10 8.14662013e-10 8.64130574e-10 4.16949511e-10
#  1.50113833e-09 2.84035073e-09 3.22358255e-10 2.98608376e-10
#  2.70573623e-10 5.59426277e-11]
# Mean: 8.208263359574285e-10
# Standard deviation: 7.820068731767884e-10

# %%
df_lin = train_set["Year"]
GHGs_linPredict = pd.DataFrame(GHGs_linPredict)
GHGs_linPredict=GHGs_linPredict.to_numpy()
df_lin=df_lin.to_numpy()
GHGs_linPredict=GHGs_linPredict.reshape((np.size(GHGs_linPredict)),1)
df_lin = df_lin.reshape((np.size(df_lin),1))
GHGs_linPredict=np.concatenate((GHGs_linPredict,df_lin), axis = 1)
GHGs_linPredict= pd.DataFrame(GHGs_linPredict)
predict_LinResult = np.zeros(np.size(Years))
predict_LinResult[0]
for i in range(2004,2021):
  a = i-2004
  predict_LinResult[a]=np.sum(GHGs_linPredict.loc[GHGs_linPredict[1]==i].to_numpy())

# %%
plt.plot(Years, predict_LinResult, 'b--' , label="Predicted Emissions (Linear Regression)")
plt.plot(Years, np.array(Years_CO2) + np.array(Years_CH4) + np.array(Years_HFC) + np.array(Years_N2O) +np.array(Years_PFC) + np.array(Years_SF6), 'r--', label="Actual Emissions")
plt.xlabel("Years")
plt.ylabel("Metric Tons eCO2")
plt.legend(loc="lower left")

# %%
GHGs_labels.hist(bins=50,edgecolor='b')
plt.title('Histogram of Total CO2 Values')
# Out:
# Text(0.5, 1.0, 'Histogram of Total CO2 Values')

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(GHGs_predict, GHGs_labels)
GHGs_predictions_forest = forest_reg.predict(GHGs_predict)
forest_mse = mean_squared_error(GHGs_labels, GHGs_predictions_forest)
forest_rmse = np.sqrt(forest_mse)

forest_rmse
# Out:
# 8393.028392118895

# %%
GHGs_predictions_forest.shape
# Out:
# (3729,)

# %%
scores = cross_val_score(forest_reg, GHGs_prepared, GHGs_labels, scoring = "neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [17250.97716215  9521.8222256  40789.40682632 17468.12621977
#  16023.44329585 25717.21704199 26159.90127156 11324.54914681
#   9147.37916303 19330.26989337]
# Mean: 19273.309224644705
# Standard deviation: 9113.80098964907

# %% [markdown]
# # Grid Search

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [{'n_estimators': [3,10,30], 'max_features': [2,4,5,8]}, {'bootstrap': [False], 'n_estimators': [3,10], 'max_features': [2,3,4]},]

forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=5, scoring = 'neg_mean_squared_error', return_train_score = True)
grid_search.fit(GHGs_prepared, GHGs_labels)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_features': [2, 4, 5, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
  print(np.sqrt(-mean_score), params)
# Out:
# 161252.5736629579 {'max_features': 2, 'n_estimators': 3}
# 149040.51477742096 {'max_features': 2, 'n_estimators': 10}
# 98087.6887649266 {'max_features': 2, 'n_estimators': 30}
# 81320.0869262419 {'max_features': 4, 'n_estimators': 3}
# 58463.70066457701 {'max_features': 4, 'n_estimators': 10}
# 45833.73498199169 {'max_features': 4, 'n_estimators': 30}
# 63613.685250538896 {'max_features': 5, 'n_estimators': 3}
# 36252.24075982903 {'max_features': 5, 'n_estimators': 10}
# 35546.323772481526 {'max_features': 5, 'n_estimators': 30}
# 37159.03954492055 {'max_features': 8, 'n_estimators': 3}
# 28141.06873681963 {'max_features': 8, 'n_estimators': 10}
# 26553.58395544432 {'max_features': 8, 'n_estimators': 30}
# 121278.9649436687 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 103044.29485449626 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 102279.17463625963 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# ...

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([9.98541788e-01, 3.39127703e-04, 1.10057666e-03, 1.46891227e-05,
#        2.03806294e-07, 3.61508458e-06])

# %%
train_set["Year"]
# Out:
# 32     2006
# 332    2020
# 411    2019
# 49     2019
# 18     2019
#        ...
# 64     2006
# 466    2020
# 131    2015
# 110    2011
# 158    2019
# Name: Year, Length: 3729, dtype: int64

# %%
GHGs_predictions_forest = pd.DataFrame(GHGs_predictions_forest)
GHGs_predictions_forest=GHGs_predictions_forest.to_numpy()
GHGs_predictions_forest=GHGs_predictions_forest.reshape((np.size(GHGs_predictions_forest)),1)
GHGs_predictions_forest=np.concatenate((GHGs_predictions_forest,df), axis = 1)
GHGs_predictions_forest = pd.DataFrame(GHGs_predictions_forest)

# %%
predict_result = np.zeros(np.size(Years))
predict_result[0]
for i in range(2004,2021):
  a = i-2004
  predict_result[a]=np.sum(GHGs_predictions_forest.loc[GHGs_predictions_forest[1]==i].to_numpy())

# %% [markdown]
# Plot: Prediction of Total emissions for each year

# %%
plt.plot(Years, predict_result, 'b--', label='Predicted Emissions (Random Forest Model)')
plt.plot(Years, np.array(Years_CO2) + np.array(Years_CH4) + np.array(Years_HFC) + np.array(Years_N2O) +np.array(Years_PFC) + np.array(Years_SF6), 'r--', label="Actual Emissions")
plt.xlabel("Years")
plt.ylabel("Metric Tons CO2e")
plt.legend(loc="lower left")

# %%
GHGs_predictions_forest.isnull().any()
# Out:
# 0    False
# 1    False
# dtype: bool
